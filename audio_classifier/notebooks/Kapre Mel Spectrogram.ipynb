# %%
import tensorflow as tf
from tensorflow.keras.layers import LayerNormalization
import kapre
from tensorflow.keras.models import Sequential
from kapre.composed import get_melspectrogram_layer, get_log_frequency_spectrogram_layer
import numpy as np
import librosa
import matplotlib.pyplot as plt
from scipy.io import wavfile
from tensorflow.keras.layers import Input

# %%
def visualise_model(X):
    fig, ax = plt.subplots(figsize=(10,8))
    ax.set_title('Normalized Frequency Spectrogram', size=20)
    ax.imshow(X)
    ax.set_ylabel('Mel bins', size=18)
    ax.set_xlabel('Time (10 ms)', size=18)
    ax.xaxis.set_tick_params(labelsize=14)
    ax.yaxis.set_tick_params(labelsize=14)
    plt.show()

# %%
src, sr = librosa.load('../clean/9mm/9mm5yrds_aux_shot1_1.wav', sr=None, mono=True)
print('Audio length: %d samples, %04.2f seconds. \n' % (len(src), len(src) / sr) +
      'Audio sample rate: %d Hz' % sr)
dt = 1.0
_src = src[:int(sr*dt)]
src = np.expand_dims(_src, axis=1)
input_shape = src.shape
print(input_shape)
# Out:
# Audio length: 16000 samples, 1.00 seconds.
# Audio sample rate: 16000 Hz
# (16000, 1)

# %%
# Parameters
input_shape = (16000, 1)  # Assuming mono audio with 16000 samples
sr = 16000  # Sample rate

# Mel-spectrogram layer
melgram = get_melspectrogram_layer(
    input_shape=input_shape,
    n_mels=128,
    mel_norm='slaney',
    pad_end=True,
    n_fft=512,
    win_length=400,
    hop_length=160,
    sample_rate=sr,
    db_ref_value=1.0,
    return_decibel=True,
    input_data_format='channels_last',
    output_data_format='channels_last'
)

# Normalization layer
norm = LayerNormalization(axis=2)

# Model definition
model = Sequential()
model.add(Input(shape=input_shape))  # Explicitly define input shape
model.add(melgram)
model.add(norm)

# Summary
model.summary()
# Out:
# C:\Users\Leona\anaconda3\envs\audio\Lib\site-packages\kapre\time_frequency.py:111: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super(STFT, self).__init__(**kwargs)
# WARNING:tensorflow:From C:\Users\Leona\anaconda3\envs\audio\Lib\site-packages\keras\src\backend\tensorflow\core.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ melspectrogram (Sequential)          │ (None, 100, 128, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization                  │ (None, 100, 128, 1)         │             256 │
# │ (LayerNormalization)                 │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 256 (1.00 KB)
#  Trainable params: 256 (1.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch = np.expand_dims(src, axis=0)
X = model.predict(batch).squeeze().T
visualise_model(X)

plt.title('Normalized Frequency Histogram')
plt.hist(X.flatten(), bins='auto')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
